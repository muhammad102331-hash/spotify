# %% [markdown]
# # EDA SPOTIFY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"E:\Project\spotify\spotify .csv")

# %%
df.head()
# Out:
#          date  position               song                      artist  \
# 0  2023-05-18         1    Ella Baila Sola              Eslabon Armado
# 1  2023-05-18         2          un x100to  Grupo Frontera & Bad Bunny
# 2  2023-05-18         3    La Bebe - Remix      Yng Lvcas & Peso Pluma
# 3  2023-05-18         4  Cupid - Twin Ver.                 FIFTY FIFTY
# 4  2023-05-18         5            Flowers                 Miley Cyrus
#
#    popularity  duration_ms album_type  total_tracks release_date  is_explicit  \
# 0          89       165671      album            16   2023-04-28        False
# 1          99       194563     single             1   2023-04-17        False
# 2          99       234352     single             2   2023-03-17         True
# 3          97       174253     single             3   2023-02-24        False
# 4          91       200600      album            13   2023-03-10        False
#
#                                      album_cover_url
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27800 entries, 0 to 27799
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             27800 non-null  object
#  1   position         27800 non-null  int64
#  2   song             27800 non-null  object
#  3   artist           27800 non-null  object
#  4   popularity       27800 non-null  int64
#  5   duration_ms      27800 non-null  int64
#  6   album_type       27800 non-null  object
#  7   total_tracks     27800 non-null  int64
#  8   release_date     27800 non-null  object
#  9   is_explicit      27800 non-null  bool
#  10  album_cover_url  27800 non-null  object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 2.1+ MB

# %%
# Convert 'date' and 'release_date' columns to datetime
df['date'] = pd.to_datetime(df['date'])
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# Check for any missing values again after data conversion
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Convert 'date' and 'release_date' columns to datetime
#       2 df['date'] = pd.to_datetime(df['date'])
# ----> 3 df['release_date'] = pd.to_datetime(df['release_date'])
#       5 # Check for any missing values again after data conversion
#       6 print(df.isnull().sum())
#
# File e:\EMiniconda3\envs\y_dtale\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# ...
